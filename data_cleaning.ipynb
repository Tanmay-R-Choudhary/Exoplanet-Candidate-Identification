# %%
import pandas as pd
from matplotlib import pylab as plt
import seaborn as sns
import numpy as np
import os

# %%
pd.set_option("display.max_columns", 200)
plt.style.use("ggplot")

# %%
df = pd.read_csv('data/cumulative.csv')
df
# Out:
#       rowid     kepid kepoi_name   kepler_name koi_disposition  \
# 0         1  10797460  K00752.01  Kepler-227 b       CONFIRMED
# 1         2  10797460  K00752.02  Kepler-227 c       CONFIRMED
# 2         3  10811496  K00753.01           NaN  FALSE POSITIVE
# 3         4  10848459  K00754.01           NaN  FALSE POSITIVE
# 4         5  10854555  K00755.01  Kepler-664 b       CONFIRMED
# ...     ...       ...        ...           ...             ...
# 9559   9560  10031643  K07984.01           NaN  FALSE POSITIVE
# 9560   9561  10090151  K07985.01           NaN  FALSE POSITIVE
# 9561   9562  10128825  K07986.01           NaN       CANDIDATE
# 9562   9563  10147276  K07987.01           NaN  FALSE POSITIVE
# 9563   9564  10156110  K07989.01           NaN  FALSE POSITIVE
#
#      koi_pdisposition  koi_score  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  \
# 0           CANDIDATE      1.000              0              0              0
# ...

# %%
df.columns
# Out:
# Index(['rowid', 'kepid', 'kepoi_name', 'kepler_name', 'koi_disposition',
#        'koi_pdisposition', 'koi_score', 'koi_fpflag_nt', 'koi_fpflag_ss',
#        'koi_fpflag_co', 'koi_fpflag_ec', 'koi_period', 'koi_period_err1',
#        'koi_period_err2', 'koi_time0bk', 'koi_time0bk_err1',
#        'koi_time0bk_err2', 'koi_impact', 'koi_impact_err1', 'koi_impact_err2',
#        'koi_duration', 'koi_duration_err1', 'koi_duration_err2', 'koi_depth',
#        'koi_depth_err1', 'koi_depth_err2', 'koi_prad', 'koi_prad_err1',
#        'koi_prad_err2', 'koi_teq', 'koi_teq_err1', 'koi_teq_err2', 'koi_insol',
#        'koi_insol_err1', 'koi_insol_err2', 'koi_model_snr', 'koi_tce_plnt_num',
#        'koi_tce_delivname', 'koi_steff', 'koi_steff_err1', 'koi_steff_err2',
#        'koi_slogg', 'koi_slogg_err1', 'koi_slogg_err2', 'koi_srad',
#        'koi_srad_err1', 'koi_srad_err2', 'ra', 'dec', 'koi_kepmag'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9564 entries, 0 to 9563
# Data columns (total 50 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   rowid              9564 non-null   int64
#  1   kepid              9564 non-null   int64
#  2   kepoi_name         9564 non-null   object
#  3   kepler_name        2294 non-null   object
#  4   koi_disposition    9564 non-null   object
#  5   koi_pdisposition   9564 non-null   object
#  6   koi_score          8054 non-null   float64
#  7   koi_fpflag_nt      9564 non-null   int64
#  8   koi_fpflag_ss      9564 non-null   int64
#  9   koi_fpflag_co      9564 non-null   int64
#  10  koi_fpflag_ec      9564 non-null   int64
#  11  koi_period         9564 non-null   float64
#  12  koi_period_err1    9110 non-null   float64
#  13  koi_period_err2    9110 non-null   float64
#  14  koi_time0bk        9564 non-null   float64
#  15  koi_time0bk_err1   9110 non-null   float64
# ...

# %%
df.describe()
# Out:
#              rowid         kepid    koi_score  koi_fpflag_nt  koi_fpflag_ss  \
# count  9564.000000  9.564000e+03  8054.000000    9564.000000    9564.000000
# mean   4782.500000  7.690628e+06     0.480829       0.188206       0.231598
# std    2761.033321  2.653459e+06     0.476928       0.390897       0.421875
# min       1.000000  7.574500e+05     0.000000       0.000000       0.000000
# 25%    2391.750000  5.556034e+06     0.000000       0.000000       0.000000
# 50%    4782.500000  7.906892e+06     0.334000       0.000000       0.000000
# 75%    7173.250000  9.873066e+06     0.998000       0.000000       0.000000
# max    9564.000000  1.293514e+07     1.000000       1.000000       1.000000
#
#        koi_fpflag_co  koi_fpflag_ec     koi_period  koi_period_err1  \
# count    9564.000000    9564.000000    9564.000000      9110.000000
# mean        0.194898       0.120033      75.671358         0.002148
# std         0.396143       0.325018    1334.744046         0.008236
# ...

# %%
df.isna().sum()
# Out:
# rowid                   0
# kepid                   0
# kepoi_name              0
# kepler_name          7270
# koi_disposition         0
# koi_pdisposition        0
# koi_score            1510
# koi_fpflag_nt           0
# koi_fpflag_ss           0
# koi_fpflag_co           0
# koi_fpflag_ec           0
# koi_period              0
# koi_period_err1       454
# koi_period_err2       454
# koi_time0bk             0
# koi_time0bk_err1      454
# koi_time0bk_err2      454
# koi_impact            363
# koi_impact_err1       454
# koi_impact_err2       454
# koi_duration            0
# koi_duration_err1     454
# koi_duration_err2     454
# koi_depth             363
# koi_depth_err1        454
# koi_depth_err2        454
# koi_prad              363
# koi_prad_err1         363
# koi_prad_err2         363
# koi_teq               363
# koi_teq_err1         9564
# koi_teq_err2         9564
# koi_insol             321
# koi_insol_err1        321
# koi_insol_err2        321
# ...

# %%
df.shape
# Out:
# (9564, 50)

# %% [markdown]
# Lets drop some columns

# %%
df.columns
# Out:
# Index(['rowid', 'kepid', 'kepoi_name', 'kepler_name', 'koi_disposition',
#        'koi_pdisposition', 'koi_score', 'koi_fpflag_nt', 'koi_fpflag_ss',
#        'koi_fpflag_co', 'koi_fpflag_ec', 'koi_period', 'koi_period_err1',
#        'koi_period_err2', 'koi_time0bk', 'koi_time0bk_err1',
#        'koi_time0bk_err2', 'koi_impact', 'koi_impact_err1', 'koi_impact_err2',
#        'koi_duration', 'koi_duration_err1', 'koi_duration_err2', 'koi_depth',
#        'koi_depth_err1', 'koi_depth_err2', 'koi_prad', 'koi_prad_err1',
#        'koi_prad_err2', 'koi_teq', 'koi_teq_err1', 'koi_teq_err2', 'koi_insol',
#        'koi_insol_err1', 'koi_insol_err2', 'koi_model_snr', 'koi_tce_plnt_num',
#        'koi_tce_delivname', 'koi_steff', 'koi_steff_err1', 'koi_steff_err2',
#        'koi_slogg', 'koi_slogg_err1', 'koi_slogg_err2', 'koi_srad',
#        'koi_srad_err1', 'koi_srad_err2', 'ra', 'dec', 'koi_kepmag'],
#       dtype='object')

# %%
df = df[[
    #'rowid', 'kepid', 'kepoi_name', 'kepler_name', 
    'koi_disposition',
    'koi_pdisposition', 'koi_score', 'koi_fpflag_nt', 'koi_fpflag_ss',
    'koi_fpflag_co', 'koi_fpflag_ec', 'koi_period', 'koi_period_err1',
    'koi_period_err2', 'koi_time0bk', 'koi_time0bk_err1',
    'koi_time0bk_err2', 'koi_impact', 'koi_impact_err1', 'koi_impact_err2',
    'koi_duration', 'koi_duration_err1', 'koi_duration_err2', 'koi_depth',
    'koi_depth_err1', 'koi_depth_err2', 'koi_prad', 'koi_prad_err1',
    'koi_prad_err2', 'koi_teq', 'koi_teq_err1', 'koi_teq_err2', 'koi_insol',
    'koi_insol_err1', 'koi_insol_err2', 'koi_model_snr', 'koi_tce_plnt_num',
    'koi_tce_delivname', 'koi_steff', 'koi_steff_err1', 'koi_steff_err2',
    'koi_slogg', 'koi_slogg_err1', 'koi_slogg_err2', 'koi_srad',
    'koi_srad_err1', 'koi_srad_err2', 'ra', 'dec', 'koi_kepmag']].copy()

df.head()
# Out:
#   koi_disposition koi_pdisposition  koi_score  koi_fpflag_nt  koi_fpflag_ss  \
# 0       CONFIRMED        CANDIDATE      1.000              0              0
# 1       CONFIRMED        CANDIDATE      0.969              0              0
# 2  FALSE POSITIVE   FALSE POSITIVE      0.000              0              1
# 3  FALSE POSITIVE   FALSE POSITIVE      0.000              0              1
# 4       CONFIRMED        CANDIDATE      1.000              0              0
#
#    koi_fpflag_co  koi_fpflag_ec  koi_period  koi_period_err1  koi_period_err2  \
# 0              0              0    9.488036     2.775000e-05    -2.775000e-05
# 1              0              0   54.418383     2.479000e-04    -2.479000e-04
# 2              0              0   19.899140     1.494000e-05    -1.494000e-05
# 3              0              0    1.736952     2.630000e-07    -2.630000e-07
# 4              0              0    2.525592     3.761000e-06    -3.761000e-06
#
# ...

# %%
df.koi_disposition.value_counts()
# Out:
# koi_disposition
# FALSE POSITIVE    5023
# CONFIRMED         2293
# CANDIDATE         2248
# Name: count, dtype: int64

# %%
df = df[df.koi_disposition.isin(['FALSE POSITIVE', 'CONFIRMED'])].copy()

# %%
df = df.drop('koi_pdisposition', axis=1).copy()

# %%
df.head()
# Out:
#   koi_disposition  koi_score  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  \
# 0       CONFIRMED      1.000              0              0              0
# 1       CONFIRMED      0.969              0              0              0
# 2  FALSE POSITIVE      0.000              0              1              0
# 3  FALSE POSITIVE      0.000              0              1              0
# 4       CONFIRMED      1.000              0              0              0
#
#    koi_fpflag_ec  koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# 0              0    9.488036     2.775000e-05    -2.775000e-05   170.538750
# 1              0   54.418383     2.479000e-04    -2.479000e-04   162.513840
# 2              0   19.899140     1.494000e-05    -1.494000e-05   175.850252
# 3              0    1.736952     2.630000e-07    -2.630000e-07   170.307565
# 4              0    2.525592     3.761000e-06    -3.761000e-06   171.595550
#
# ...

# %%
df.shape
# Out:
# (7316, 45)

# %% [markdown]
# Score column is nto needed. Our target column is koi_disposition

# %%
df = df.drop('koi_score', axis=1).copy()

# %%
df.head()
# Out:
#   koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0       CONFIRMED              0              0              0              0
# 1       CONFIRMED              0              0              0              0
# 2  FALSE POSITIVE              0              1              0              0
# 3  FALSE POSITIVE              0              1              0              0
# 4       CONFIRMED              0              0              0              0
#
#    koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# 0    9.488036     2.775000e-05    -2.775000e-05   170.538750
# 1   54.418383     2.479000e-04    -2.479000e-04   162.513840
# 2   19.899140     1.494000e-05    -1.494000e-05   175.850252
# 3    1.736952     2.630000e-07    -2.630000e-07   170.307565
# 4    2.525592     3.761000e-06    -3.761000e-06   171.595550
#
#    koi_time0bk_err1  koi_time0bk_err2  koi_impact  koi_impact_err1  \
# ...

# %%
df.isna().sum()
# Out:
# koi_disposition         0
# koi_fpflag_nt           0
# koi_fpflag_ss           0
# koi_fpflag_co           0
# koi_fpflag_ec           0
# koi_period              0
# koi_period_err1       377
# koi_period_err2       377
# koi_time0bk             0
# koi_time0bk_err1      377
# koi_time0bk_err2      377
# koi_impact            300
# koi_impact_err1       377
# koi_impact_err2       377
# koi_duration            0
# koi_duration_err1     377
# koi_duration_err2     377
# koi_depth             300
# koi_depth_err1        377
# koi_depth_err2        377
# koi_prad              300
# koi_prad_err1         300
# koi_prad_err2         300
# koi_teq               300
# koi_teq_err1         7316
# koi_teq_err2         7316
# koi_insol             259
# koi_insol_err1        259
# koi_insol_err2        259
# koi_model_snr         300
# koi_tce_plnt_num      279
# koi_tce_delivname     279
# koi_steff             300
# koi_steff_err1        397
# koi_steff_err2        412
# ...

# %% [markdown]
# koi_teq_err1 and koi_teq_err2 are uncertainties in koi_teq. Since the entire column is empty, it is better to drop it entirely

# %%
df = df.drop(['koi_teq_err1', 'koi_teq_err2'], axis=1).copy()

# %%
df.isna().sum()
# Out:
# koi_disposition        0
# koi_fpflag_nt          0
# koi_fpflag_ss          0
# koi_fpflag_co          0
# koi_fpflag_ec          0
# koi_period             0
# koi_period_err1      377
# koi_period_err2      377
# koi_time0bk            0
# koi_time0bk_err1     377
# koi_time0bk_err2     377
# koi_impact           300
# koi_impact_err1      377
# koi_impact_err2      377
# koi_duration           0
# koi_duration_err1    377
# koi_duration_err2    377
# koi_depth            300
# koi_depth_err1       377
# koi_depth_err2       377
# koi_prad             300
# koi_prad_err1        300
# koi_prad_err2        300
# koi_teq              300
# koi_insol            259
# koi_insol_err1       259
# koi_insol_err2       259
# koi_model_snr        300
# koi_tce_plnt_num     279
# koi_tce_delivname    279
# koi_steff            300
# koi_steff_err1       397
# koi_steff_err2       412
# koi_slogg            300
# koi_slogg_err1       397
# koi_slogg_err2       397
# koi_srad             300
# ...

# %% [markdown]
# Are the uncertainty columns adding anything? Ideally the uncertainty of equipment should be really small.

# %%
df.columns
# Out:
# Index(['koi_disposition', 'koi_fpflag_nt', 'koi_fpflag_ss', 'koi_fpflag_co',
#        'koi_fpflag_ec', 'koi_period', 'koi_period_err1', 'koi_period_err2',
#        'koi_time0bk', 'koi_time0bk_err1', 'koi_time0bk_err2', 'koi_impact',
#        'koi_impact_err1', 'koi_impact_err2', 'koi_duration',
#        'koi_duration_err1', 'koi_duration_err2', 'koi_depth', 'koi_depth_err1',
#        'koi_depth_err2', 'koi_prad', 'koi_prad_err1', 'koi_prad_err2',
#        'koi_teq', 'koi_insol', 'koi_insol_err1', 'koi_insol_err2',
#        'koi_model_snr', 'koi_tce_plnt_num', 'koi_tce_delivname', 'koi_steff',
#        'koi_steff_err1', 'koi_steff_err2', 'koi_slogg', 'koi_slogg_err1',
#        'koi_slogg_err2', 'koi_srad', 'koi_srad_err1', 'koi_srad_err2', 'ra',
#        'dec', 'koi_kepmag'],
#       dtype='object')

# %%
uncertainty_columns = [
       'koi_period_err1', 'koi_period_err2',
       'koi_time0bk_err1', 'koi_time0bk_err2',
       'koi_impact_err1', 'koi_impact_err2',
       'koi_duration_err1', 'koi_duration_err2', 'koi_depth_err1',
       'koi_depth_err2', 'koi_prad_err1', 'koi_prad_err2',
       'koi_insol_err1', 'koi_insol_err2',
       'koi_steff_err1', 'koi_steff_err2', 'koi_slogg_err1',
       'koi_slogg_err2', 'koi_srad_err1', 'koi_srad_err2']

# %%
len(uncertainty_columns)
# Out:
# 20

# %%
plt.figure(figsize=(30, 30))
for idx, col in enumerate(uncertainty_columns):
    plt.subplot(5, 4, idx + 1)
    ax = sns.histplot(x=df[col], bins=90)
    plt.xticks(rotation=45)

plt.show()

# %%
uncertainty_columns
# Out:
# ['koi_period_err1',
#  'koi_period_err2',
#  'koi_time0bk_err1',
#  'koi_time0bk_err2',
#  'koi_impact_err1',
#  'koi_impact_err2',
#  'koi_duration_err1',
#  'koi_duration_err2',
#  'koi_depth_err1',
#  'koi_depth_err2',
#  'koi_prad_err1',
#  'koi_prad_err2',
#  'koi_insol_err1',
#  'koi_insol_err2',
#  'koi_steff_err1',
#  'koi_steff_err2',
#  'koi_slogg_err1',
#  'koi_slogg_err2',
#  'koi_srad_err1',
#  'koi_srad_err2']

# %%
uncertainty_keep_cols = [
 'koi_time0bk_err1',
 'koi_time0bk_err2',
 'koi_duration_err1',
 'koi_duration_err2',
 'koi_steff_err1',
 'koi_steff_err2',
 'koi_slogg_err1',
 'koi_slogg_err2',
]

uncertainty_drop_cols = [i for i in uncertainty_columns if i not in uncertainty_keep_cols]

# %%
uncertainty_drop_cols
# Out:
# ['koi_period_err1',
#  'koi_period_err2',
#  'koi_impact_err1',
#  'koi_impact_err2',
#  'koi_depth_err1',
#  'koi_depth_err2',
#  'koi_prad_err1',
#  'koi_prad_err2',
#  'koi_insol_err1',
#  'koi_insol_err2',
#  'koi_srad_err1',
#  'koi_srad_err2']

# %%
df = df.drop(uncertainty_drop_cols, axis=1).copy()

# %%
df.shape
# Out:
# (7316, 30)

# %%
df.head()
# Out:
#   koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0       CONFIRMED              0              0              0              0
# 1       CONFIRMED              0              0              0              0
# 2  FALSE POSITIVE              0              1              0              0
# 3  FALSE POSITIVE              0              1              0              0
# 4       CONFIRMED              0              0              0              0
#
#    koi_period  koi_time0bk  koi_time0bk_err1  koi_time0bk_err2  koi_impact  \
# 0    9.488036   170.538750          0.002160         -0.002160       0.146
# 1   54.418383   162.513840          0.003520         -0.003520       0.586
# 2   19.899140   175.850252          0.000581         -0.000581       0.969
# 3    1.736952   170.307565          0.000115         -0.000115       1.276
# 4    2.525592   171.595550          0.001130         -0.001130       0.701
#
# ...

# %%
df.tail()
# Out:
#      koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  \
# 9556  FALSE POSITIVE              0              1              0
# 9559  FALSE POSITIVE              0              0              0
# 9560  FALSE POSITIVE              0              1              1
# 9562  FALSE POSITIVE              0              0              1
# 9563  FALSE POSITIVE              0              0              1
#
#       koi_fpflag_ec  koi_period  koi_time0bk  koi_time0bk_err1  \
# 9556              0   23.627035   150.036200           0.01090
# 9559              1    8.589871   132.016100           0.01570
# 9560              0    0.527699   131.705093           0.00017
# 9562              0    0.681402   132.181750           0.00285
# 9563              1    4.856035   135.993300           0.01080
#
#       koi_time0bk_err2  koi_impact  koi_duration  koi_duration_err1  \
# 9556          -0.01090       1.096       11.4810             0.1600
# ...

# %%
df.isna().sum()
# Out:
# koi_disposition        0
# koi_fpflag_nt          0
# koi_fpflag_ss          0
# koi_fpflag_co          0
# koi_fpflag_ec          0
# koi_period             0
# koi_time0bk            0
# koi_time0bk_err1     377
# koi_time0bk_err2     377
# koi_impact           300
# koi_duration           0
# koi_duration_err1    377
# koi_duration_err2    377
# koi_depth            300
# koi_prad             300
# koi_teq              300
# koi_insol            259
# koi_model_snr        300
# koi_tce_plnt_num     279
# koi_tce_delivname    279
# koi_steff            300
# koi_steff_err1       397
# koi_steff_err2       412
# koi_slogg            300
# koi_slogg_err1       397
# koi_slogg_err2       397
# koi_srad             300
# ra                     0
# dec                    0
# koi_kepmag             1
# dtype: int64

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [koi_disposition, koi_fpflag_nt, koi_fpflag_ss, koi_fpflag_co, koi_fpflag_ec, koi_period, koi_time0bk, koi_time0bk_err1, koi_time0bk_err2, koi_impact, koi_duration, koi_duration_err1, koi_duration_err2, koi_depth, koi_prad, koi_teq, koi_insol, koi_model_snr, koi_tce_plnt_num, koi_tce_delivname, koi_steff, koi_steff_err1, koi_steff_err2, koi_slogg, koi_slogg_err1, koi_slogg_err2, koi_srad, ra, dec, koi_kepmag]
# Index: []

# %%
df = df.drop(['koi_tce_delivname', 'koi_tce_plnt_num'], axis=1).copy() # object columns that contain names and ids

# %%
df.columns
# Out:
# Index(['koi_disposition', 'koi_fpflag_nt', 'koi_fpflag_ss', 'koi_fpflag_co',
#        'koi_fpflag_ec', 'koi_period', 'koi_time0bk', 'koi_time0bk_err1',
#        'koi_time0bk_err2', 'koi_impact', 'koi_duration', 'koi_duration_err1',
#        'koi_duration_err2', 'koi_depth', 'koi_prad', 'koi_teq', 'koi_insol',
#        'koi_model_snr', 'koi_steff', 'koi_steff_err1', 'koi_steff_err2',
#        'koi_slogg', 'koi_slogg_err1', 'koi_slogg_err2', 'koi_srad', 'ra',
#        'dec', 'koi_kepmag'],
#       dtype='object')

# %%
param_cols = [
       'koi_period', 'koi_time0bk',
       'koi_impact', 'koi_duration',
       'koi_depth', 'koi_prad', 'koi_teq', 'koi_insol',
       'koi_model_snr', 'koi_steff',
       'koi_slogg',
       'koi_srad', 'ra', 'dec', 'koi_kepmag']

# %%
len(param_cols)
# Out:
# 15

# %%
df[param_cols].dtypes
# Out:
# koi_period       float64
# koi_time0bk      float64
# koi_impact       float64
# koi_duration     float64
# koi_depth        float64
# koi_prad         float64
# koi_teq          float64
# koi_insol        float64
# koi_model_snr    float64
# koi_steff        float64
# koi_slogg        float64
# koi_srad         float64
# ra               float64
# dec              float64
# koi_kepmag       float64
# dtype: object

# %%
plt.figure(figsize=(30, 30))
for idx, col in enumerate(param_cols):
    plt.subplot(5, 3, idx + 1)
    ax = sns.kdeplot(x=df[col])
    plt.xticks(rotation=45)

plt.show()

# %% [markdown]
# We can fill in the missing values in these columns using the mean of the column. We can also fill the error columns with their mean too.

# %%
numeric_cols = [i for i in df.columns if df[i].dtype != 'object']

# %%
df[numeric_cols] = df[numeric_cols].fillna(df[numeric_cols].mean())

# %%
df.head()
# Out:
#   koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0       CONFIRMED              0              0              0              0
# 1       CONFIRMED              0              0              0              0
# 2  FALSE POSITIVE              0              1              0              0
# 3  FALSE POSITIVE              0              1              0              0
# 4       CONFIRMED              0              0              0              0
#
#    koi_period  koi_time0bk  koi_time0bk_err1  koi_time0bk_err2  koi_impact  \
# 0    9.488036   170.538750          0.002160         -0.002160       0.146
# 1   54.418383   162.513840          0.003520         -0.003520       0.586
# 2   19.899140   175.850252          0.000581         -0.000581       0.969
# 3    1.736952   170.307565          0.000115         -0.000115       1.276
# 4    2.525592   171.595550          0.001130         -0.001130       0.701
#
# ...

# %%
df.isna().sum()
# Out:
# koi_disposition      0
# koi_fpflag_nt        0
# koi_fpflag_ss        0
# koi_fpflag_co        0
# koi_fpflag_ec        0
# koi_period           0
# koi_time0bk          0
# koi_time0bk_err1     0
# koi_time0bk_err2     0
# koi_impact           0
# koi_duration         0
# koi_duration_err1    0
# koi_duration_err2    0
# koi_depth            0
# koi_prad             0
# koi_teq              0
# koi_insol            0
# koi_model_snr        0
# koi_steff            0
# koi_steff_err1       0
# koi_steff_err2       0
# koi_slogg            0
# koi_slogg_err1       0
# koi_slogg_err2       0
# koi_srad             0
# ra                   0
# dec                  0
# koi_kepmag           0
# dtype: int64

# %%
df.dtypes
# Out:
# koi_disposition       object
# koi_fpflag_nt          int64
# koi_fpflag_ss          int64
# koi_fpflag_co          int64
# koi_fpflag_ec          int64
# koi_period           float64
# koi_time0bk          float64
# koi_time0bk_err1     float64
# koi_time0bk_err2     float64
# koi_impact           float64
# koi_duration         float64
# koi_duration_err1    float64
# koi_duration_err2    float64
# koi_depth            float64
# koi_prad             float64
# koi_teq              float64
# koi_insol            float64
# koi_model_snr        float64
# koi_steff            float64
# koi_steff_err1       float64
# koi_steff_err2       float64
# koi_slogg            float64
# koi_slogg_err1       float64
# koi_slogg_err2       float64
# koi_srad             float64
# ra                   float64
# dec                  float64
# koi_kepmag           float64
# dtype: object

# %%
df.to_csv("data/cleaned_data.csv")
